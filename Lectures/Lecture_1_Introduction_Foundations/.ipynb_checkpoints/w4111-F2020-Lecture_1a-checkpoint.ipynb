# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
#
# }
#
# </style>
#
# <b><center>
#     <span style="font-size: 24pt; line-height: 1.2;">COMS W4111: Introduction to Databases</span><br>
#     <span style="font-size: 24pt; line-height: 1.2;">Section 002, Spring, 2020</span><br>
# </center></b>
# <br><br>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2;">Lecture 1: Introduction, Course Overview, Foundational Concepts</span>
# </center></i>

# %% [markdown]
# __Note:__ Modifying width of cells for wider displays.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
display(HTML("<style>.output_result { max-width:80% !important; }</style>"))
display(HTML("<style>.prompt { display:none !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>
# <style>.output_result { max-width:80% !important; }</style>
# <style>.prompt { display:none !important; }</style>

# %% [markdown]
# __Example:__ This is a photo of mean using a database to match service members to requests for personnel based on assignment needs and service member skills. The hardhat is because DB usage can be very dangerous 😱.
#
# | <img src="../../images/nygdb.jpg" width="500px;"> |
# | :---: |
# | __Using a Database__ |

# %% [markdown]
# <br><br>
#
# ### Course Objectives
#
# <br><br>
#
# - Have fun, learn a lot and come to appreciate and enjoy some amazing technology.
#
#
# - Provide a foundation that allows you to succeed in future courses. This is an _introduction_ to databases. The technology is crucial for future courses
#     - Advanced database classes
#     - Machine learning
#     - Big data, data analysis
#     - Numerical, simulation and analytics in operations research, engineering, economics, finance, life sciences, etc.
#
#
# - Enable you to successfully apply the technology in your work and profession.
#
# <br>
# <div class="cool" style="text-align:center;color:red;font-size:300%;line-height:1.2;">Have cool stuff to talk about on interviews and in your resumes.</div>
# <br>

# %% [markdown]
# <br><br>
#
# ### Organization and Logistics
# <br><br>
# - Lecture: Friday, 10:10 AM-12:40 PM, Room TBD
# <br><br>
#
# - Instructor: Donald F. Ferguson (dff@cs.columbia.edu)
# <br><br>
#
# - Office Hours:
#     - Fridays: 8:30 AM - 10:00 PM, 1:00 - 2:00 PM, 4:00 PM - 6:00 PM.
#         - Location TBD
#         - Will hold on-line office hours.
#     - By appointment, as needed, as available.
#     - I hold a lot of extra office hours, usually on weekends.
#         - I typically post on Piazza when I will have extra availability.
#         - The extra OHs may be "recitations," in which I go over exam questions, homework, etc.
#         - Extra OH and recitations are often on the weekend or in the evening.
#     - I will be flexible about timezones for extra office hours to accommodate students.
# <br><br>
#
# - __Recitation Section R02:__ This is an optional recitation/office hours. It will be in person (when possible) and on-line. You do not need to register for it.
#
# - Collaboration/Contact/Content:
#     - The class is on [Piazza](https://piazza.com/class/kd7mco27ygz5ew)
#         - General questions
#         - Clarification of homeworks, class material, etc.
#     - The course lectures, sample code, etc. will be on GitHub.
#         - GitHub home page (https://donald-f-ferguson.github.io/IntroductionToDatabases_F20/)
#         - Repository/Project (https://github.com/donald-f-ferguson/IntroductionToDatabases_F20)
#     - Course Assistants: See above
#     - There is a [Slack Team/Group](https://join.slack.com/t/dff-columbia/shared_invite/zt-3mnfb5it-MaZbLZRd9vGg06M5ueC8Zw) for my courses. Please join the channel ```w4111-f2w.```
# <br><br>

# %% [markdown]
# <br>
#
# ### Environment and material
# <br>
#
# - Primary content is in lectures and references.
# <br><br>
# - Recommended textbook:
#     - __Database System Concepts 7th Edition,__, Abraham Silberschatz, Henry Korth,  S. Sudarshan. ISBN-13: 978-0078022159
#     - We will cover a subset of the material in the textbook, and in a different order.
#     - There is a [website](https://www.db-book.com/db7/index.html) for the book that has PowerPoint, samples, etc.
# <br><br>
# - I will bring in examples from industry, engineering and practical experience.
# <br><br>
# - Lecture material and examples:
#     - Will be Jupyter Notebooks (http://jupyter.org/) and PowerPoint for most lectures. I usually install the full [Anaconda suite.](https://www.anaconda.com/download)
#     - There is a site associated with the textbook that contains the slides, database schema, examples, etc. (https://www.db-book.com/db7/).
#     - Notebooks, slides, sample code, etc. will be available on [GitHub project](https://github.com/donald-f-ferguson/IntroToDatabases_F20) for the course. The easiest approach is to clone the project repository.

# %% [markdown]
# <br>
#
# ### Programming and Non-Programming
# <br>
#
# - Programming Track: Project and development;
#     - We will  use Python.
#     - Database engines and tools
#         - We will start with the relational data model. Please install the latest versions of
#             - [MySQL](https://dev.mysql.com/downloads/mysql/)
#             - [MySQL Workbench](https://dev.mysql.com/downloads/mysql/).
#         - We will also use [Neo4j](https://neo4j.com/), [CouchDB](http://couchdb.apache.org/) and Redis (https://redis.io/), but you do not need to install now.
#         - I will try to cover [DynamoDB](https://aws.amazon.com/dynamodb/), [DocumentDB](https://aws.amazon.com/documentdb/) and [Firebase Realtime Database](https://firebase.google.com/docs/database/), which are cloud DBs.
#     - [Integrated Development Environments](https://en.wikipedia.org/wiki/Integrated_development_environment) for the _programming track._
#         - The [JetBrains](https://www.jetbrains.com/student/) tools are free for students, and useful for Python, JavaScript and Java. __I strongly recommend you use an IDE developing code.__ Install the __Professional Edition__ and get a free student license.
#     <br><br>
#
# - Non-programming track:
#     - I am trying to arrange for you to not have to install (too much) SW.
#     - Installing the MySQL stuff is probably a good idea but not necessary.
#     - Net: You do not have to install anything right now, other than Anaconda.
#     - You will work with the same set of databases, e.g. relational, Neo4j, ...
# <br><br>
#
# - Both Tracks: I will use Ananconda/Jupyter for most of the lectures and examples. You MUST to install
#     - Install Python 3
#     - [Anaconda Community Distribution](https://www.anaconda.com/distribution)
#     - Ananconda includes the [Spyder](https://github.com/spyder-ide/spyder), PyCharm and VisualStudio for Python. I __strongly__ prefer JetBrains but you can use VisualStudio.
#     - The IDE will be useful for non-programming track but not necessary.
# <br><br>
#
# - My normal development approach is:
#     - Develop and test code using PyCharm (IDE)
#     - Copy into Notebook when "done.
#     - Debugging is very hard without a good IDE debugger.
#     - I suggest you do the same and use PyCharm.
# <br><br>
#
#
# In lectures, I will provide links to on-line material providing definitions and optional information. I often use Wikipedia because it is a good starting point and has many references.

# %% [markdown]
# ### Course Outline

# %% [markdown]
# #### Modules
# <br>
#
# __Module I: Foundational Concepts__
#
# 1. Introduction to databases, role in applications, type of DB applications and overall system software architecture.
#
# 2. Information and data modeling and best practices, focusing on supporting application scenarios.
#
# 3. Relational data model (theory), Relational Database Management Systems, Structured Query Language, data query and update scenarios.
#
# 4. Extended topics in SQL and RDBMS (performance, security, constraints, triggers, connection management, etc).
#
# __Module II: Database Management System Implementation/Architecture__
#
# 5. Storage management, disk management, buffer management, indexes.
#
# 6. Query processing and optimization:  Query evaluation, query parsing and parse trees, operator implementation algorithms, query rewrite, query optimization techniques.
#
# 7. Concurrency control and transaction management.
#
# __Module III: NoSQL Database Overview__
#
# 8. Overview, graph databases, key-value databases, document databases.
#
# 9. Amazon S3, Amazon DynamoDB, Google Firebase/Cloud Firestore.
#
# __Module IV: Decision Support, Data Analysis__
#
# 10. Overview of schema denormalization, OLAP cubes, data analytics, machine learning.

# %% [markdown]
# # One Quick Motivating Demo

# %% [markdown]
# ## COVID-19 Data
#
# - [Institute for Health Metrics and Evaluation (IHME)](http://www.healthdata.org/about) is one of the most referenced sites for data and projections on COVID-19.
#
#
# <hr style="height:2px;">
#
# | <img src = "../../images/Screen Shot 2020-09-02 at 6.36.44 AM.png"> |
# | :---: |
# | __IHME Overview__ |
#
# <hr style="height:2px;">

# %% [markdown]
# <br><br>
# - How does a web site like this work?
#
# | <img src = "../../images/Screen Shot 2020-09-02 at 6.49.58 AM.png" width="900px;"> |
# | :---: |
# | __IHME Overview__ |
#
# <hr style="height:2px">
#
# | <img src="../../images/web_application_architecture_1.jpg"> |
# | :---: |
# | [Web Application Architecture](https://reinvently.com/blog/fundamentals-web-application-architecture/) |
#
# <hr style="height:2px">
#
# 1. An "application" runs in the browser:
#     - JavaScript code.
#     - Static content for text, images, forms, etc.
#     - User actions cause API calls to retrieve data and update display.<br><br>
# 2. There is a web server that delivers that static content using URLs.<br><br>
# 3. Programmers developed an application in Python, JavaScript, Java, ... ... that:
#     - Receives API calls.
#     - Access a "database" to retrieve requested data.
#     - Formats and returns requested data to the browser.
# <br><br>
#
#
#
# - This course covers the database aspects of many types of applications.
#
#
# - Other courses cover web applications, user interface/user experience, ... ...

# %% [markdown]
# ## "Simple" Database Examples

# %% [markdown]
# ### Getting the Data

# %% [markdown]
# - You can [manually download](http://www.healthdata.org/covid/data-downloads) the data in Zip files containing comma separate value [(CSV) format.](https://en.wikipedia.org/wiki/Comma-separated_values) CSV files are an extremely common form of sharing and distributing data between organizations and teams.
#
#
# - CSV file is an common exchange format for Excel spreadsheets, Google Sheets, ... ...
#
#
# <hr style="height:2px;">
#
# | <img src = "../../images/ihme_finder.png"> |
# | :---: |
# | __IHME Downloaded Files__ |
#
# <hr style="height:2px;">

# %% [markdown]
# - There are "read me" files explaining what is in the files.
#
# <hr style="height:2px;">
#
# | <img src = "../../images/ihme_variables.png"> |
# | :---: |
# | __IHME Read Me Files__ |

# %% [markdown]
# - The data is basically of the form:
#     - "Our data/projections on this date ..." (Folder Name)
#     - Is in this file. (CSV file name)
#
#
#
# <hr style="height:2px;">
#
# | <img src = "../../images/ihme_csv_example.png"> |
# | :---: |
# | __IHME Downloaded Files__ |
#
# <hr style="height:2px;">
#
#
#
# - Approximately 35 downloads. For each download, CSV file format:
#     - Approximately 40 columns.
#     - Approximately 50K rows.

# %% [markdown]
# - This seems like a lot of data, but is really a tiny dataset. We will see some large examples later.
#
#
#
# - Consider a specific variable, e.g. ```deaths_mean.``` The format is
#     - "On $<belief date>$, we $ <observed|projected> $"
#     - "that the ```deaths_mean``` on $<value date>$ was/would be $<value>$"
#     - "in location $<location>$."
#
#
# - The was a little confusing, put in prose. "We gathered data and ran our models on 2020-Aug-18. On this date, the reported number of deaths in NY City on May 23 was 11. The projected/predicted number of deaths on Dec. 1 is 35."
#
#
# - This can result in some interesting queries, "On 12-JUN, how many deaths did we predict for NY City on 13-OCT?"
#
#
# - There are a couple of issues with the data:
#     - The ```belief date``` is in the folder name, and not in a column in the file.
#     - For unknown reasons, there is ```location name``` that is usually the name of a state/province, but does not include the country.
#     - The site changed the formats of the files over time.
#
#
# - I had to write some icky, but not too complex Python code to clean up, standardize and load the data into a relational databases. I will share the code with you if you are interested. But, it is icky, quick and awful code.
#
# <hr style="height:2px;">
#
# | <img src = "../../images/ihme_load_process.png"> |
# | :---: |
# | __IHME Load Progress Files__ |
#
# <hr style="height:2px;">
#
#
# - Data loading, cleanup, etc. is extremely common in all aspects of using databases.

# %% [markdown]
# ### Some Simple Queries
#
# <br>
#
# - [MySQL](https://www.mysql.com/) is an [SQL](https://en.wikipedia.org/wiki/SQL) [relational database](https://en.wikipedia.org/wiki/Relational_database) product. We will cover this technology in detail.
#
#
# - I am going to install a [Jupyter/iPython Magic](https://www.tutorialspoint.com/jupyter/ipython_magic_commands.htm) to help with SQL. The plug-in is [iPython SQL.](https://pypi.org/project/ipython-sql/)

# %%
import pymysql
# %load_ext sql
# %sql mysql+pymysql://root:dbuserdbuser@localhost/AAF20W4111
# Out:
# 'Connected: root@AAF20W4111'

# %% [markdown]
# __How Many Entries in the Table__?

# %%
q_result = %sql select count(*) as count from ihme
no_rows = q_result[0]["count"]
print("\n\nThere are", round(no_rows/1000000.0,2), "million rows in the database.\n")
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 1 rows affected.
#
#
# There are 1.5 million rows in the database.

# %% [markdown]
# __What is the Maximum Number of Predicted Deaths for the United States of America?__

# %%
q_result = %sql select max(totdea_mean) as oh_darn from ihmefast where location_name = "United States of America"
oh_darn = q_result[0]["oh_darn"]
print("\n\nThe worst prediction for the US total deaths is", round(oh_darn,0), "\n")
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 1 rows affected.
#
#
# The worst prediction for the US total deaths is 295011.0

# %% [markdown]
# - SQL statement: ```select max(totdea_mean) as oh_darn from ihmefast where location_name = "United States of America"```
#
#
# - What does that statement mean?
#     - Scan all rows in the database table.
#     - For all rows with column named ```location_name``` with value "United States of America"
#     - Find the maximum value for the columna ```totdea_mean.```

# %% [markdown]
# __Which Location has the Worst Predicted Deaths?__

# %%
# %sql select location_name, round(max(totdea_mean), 0) as total_deaths from ihmefast group by location_name order by total_deaths desc limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 10 rows affected.
# [('Brazil', 383118.0),
#  ('United States of America', 295011.0),
#  ('Mexico', 118810.0),
#  ('Mexico_country', 99418.0),
#  ('US', 93765.0),
#  ('Sao Paulo', 72475.0),
#  ('Iran (Islamic Republic of)', 71548.0),
#  ('United Kingdom', 68367.0),
#  ('Philippines', 55498.0),
#  ('Russian Federation', 55314.0)]

# %% [markdown]
# __How has Maximum Death Prediction for USA Changed over Time?__

# %%
# %%sql
#
# select belief_date, round(max(totdea_mean), 0) as total_deaths from ihmefast
#     where location_name="United States of America"
#     group by belief_date order by belief_date;
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 30 rows affected.
# [(datetime.date(2020, 3, 26), 81114.0),
#  (datetime.date(2020, 3, 27), 81114.0),
#  (datetime.date(2020, 3, 29), 82141.0),
#  (datetime.date(2020, 4, 5), 81766.0),
#  (datetime.date(2020, 4, 7), 60415.0),
#  (datetime.date(2020, 4, 9), 61545.0),
#  (datetime.date(2020, 4, 12), 68841.0),
#  (datetime.date(2020, 4, 16), 60308.0),
#  (datetime.date(2020, 4, 20), 65976.0),
#  (datetime.date(2020, 4, 21), 67641.0),
#  (datetime.date(2020, 4, 26), 74073.0),
#  (datetime.date(2020, 4, 27), 72860.0),
#  (datetime.date(2020, 4, 28), 72433.0),
#  (datetime.date(2020, 5, 4), 134475.0),
#  (datetime.date(2020, 5, 8), 137184.0),
#  (datetime.date(2020, 5, 10), 147040.0),
#  (datetime.date(2020, 5, 19), 143357.0),
#  (datetime.date(2020, 5, 23), 143357.0),
#  (datetime.date(2020, 5, 28), 135109.0),
#  (datetime.date(2020, 6, 3), 150176.0),
#  (datetime.date(2020, 6, 6), 145728.0),
#  (datetime.date(2020, 6, 8), 169890.0),
# ...

# %% [markdown]
# - That was a little hard to follow. Can we do a chart?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%sql d_info << select belief_date, round(max(totdea_mean), 0) as total_deaths from ihmefast
#     where location_name="United States of America"
#     group by belief_date order by belief_date;
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 30 rows affected.
# Returning data to local variable d_info

# %%
df = pd.DataFrame(d_info)
df.columns = ['Belief Date', 'Total Deaths']
df
# Out:
#    Belief Date  Total Deaths
# 0   2020-03-26       81114.0
# 1   2020-03-27       81114.0
# 2   2020-03-29       82141.0
# 3   2020-04-05       81766.0
# 4   2020-04-07       60415.0
# 5   2020-04-09       61545.0
# 6   2020-04-12       68841.0
# 7   2020-04-16       60308.0
# 8   2020-04-20       65976.0
# 9   2020-04-21       67641.0
# 10  2020-04-26       74073.0
# 11  2020-04-27       72860.0
# 12  2020-04-28       72433.0
# 13  2020-05-04      134475.0
# 14  2020-05-08      137184.0
# 15  2020-05-10      147040.0
# 16  2020-05-19      143357.0
# 17  2020-05-23      143357.0
# 18  2020-05-28      135109.0
# 19  2020-06-03      150176.0
# 20  2020-06-06      145728.0
# 21  2020-06-08      169890.0
# 22  2020-06-13      201129.0
# 23  2020-06-24      179106.0
# 24  2020-06-27      175168.0
# 25  2020-07-04      208255.0
# 26  2020-07-11      224089.0
# 27  2020-07-18      219864.0
# 28  2020-07-26      230822.0
# 29  2020-08-06      295011.0

# %%
plt.figure(figsize=(40,20))
ax = df.plot(x='Belief Date', y='Total Deaths', figsize=(20,10))
ax.set_ylabel('Total Deaths')
# Out:
# Text(0, 0.5, 'Total Deaths')

# %% [markdown]
# - Can I get some information per state? Well, this requires me to know which locations are states, which are countries and what states are in what countries.
#
#
# - This information is not in the IHME database.

# %% [markdown]
# __What Locations do I Know About?__

# %%
import time
start_time = time.time()

# This is the actual statement. The rest is just timing it.
res = %sql select distinct location_name from ihmefast


elapsed_time = time.time() - start_time
print("Distinct locations are: \n", res)
print("Total elapsed time = ", round(elapsed_time, 3), "seconds")
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 358 rows affected.
# Distinct locations are:
#  +--------------------------------------------------------------+
# |                        location_name                         |
# +--------------------------------------------------------------+
# |                           Abruzzo                            |
# |                             Acre                             |
# |                         Afghanistan                          |
# |                        Aguascalientes                        |
# |                           Alabama                            |
# |                           Alagoas                            |
# |                            Alaska                            |
# |                           Albania                            |
# |                           Alberta                            |
# |                           Algeria                            |
# ...

# %% [markdown]
# - SQL statement: ```select distinct location_name from ihmefast```
#
#
# - Is equivalent to the following code, which I ran against a CSV with all of the records.

# %%
import csv

def get_distinct_column_values(f_name, col_name, trace_count=0):

    result = set()
    rows_read = 0

    with open(f_name, "r") as in_file:
        
        result = set()

        csv_file = csv.DictReader(in_file)

        for r in csv_file:
            rows_read += 1
            if trace_count > 0 and rows_read % trace_count == 0:
                print("Have read ", rows_read, "rows.")

            val = r.get(col_name, None)
            if val is not None:
                result.add(val)
                
    return result

# %% [markdown]
# - Let's do a timed run of the code that I wrote against a single CSV file that contains all of the entries.

# %%
d_file = "/Users/donaldferguson/Dropbox/Columbia/Courses/W4111F2020/IntroductionToDatabases_F20/Data/ihmefast.csv"
start_time = time.time()
res = get_distinct_column_values(d_file, "location_name", 0)
elapsed_time = time.time() - start_time
print("Distinct locations are: \n")
for r in res:
    print(r)
print("\n\notal elapsed time = ", round(elapsed_time, 3), "seconds")
# Out:
# Distinct locations are:
#
# Azerbaijan
# Ceará
# South Dakota
# Toscana
# Aragon
# Benin
# Coahuila
# Prince Edward Island
# Nunavut
# Luxembourg
# State of Mexico
# Bahrain
# Quintana Roo
# Nevada
# Tennessee
# Emilia-Romagna
# Saxony-Anhalt
# Ireland
# San Luis Potosi
# Durango
# Colorado
# Florida
# Iceland
# Utah
# Portugal
# Maldives
# Barbados
# Baja California
# Mali
# Arkansas
# Michigan
# Baja California Sur
# Republic of Moldova
# Spain
# Trinidad and Tobago
# Togo
# Roraima
# Andorra
# Slovakia
# Alberta
# Paraiba
# Connecticut
# New York
# Malaysia
# Puglia
# Canada
# Djibouti
# Puerto Rico
# Maranhão
# Lebanon
# Russian Federation
# Egypt
# Guinea
# Uganda
# Bavaria
# Norway
# Paraíba
# United Kingdom
# Cantabria
# Angola
# Castile and León
# Congo
# Valencian Community
# Chiapas
# Montana
# Michoacán de Ocampo
# Melilla
# Bolivia (Plurinational State of)
# Mexico City
# Tabasco
# Mozambique
# Basque Country
# United States of America
# Honduras
# Mississippi
# Denmark
# ...

# %% [markdown]
# - Some observations:
#     - The SQL statement was a lot more compact and simple.
#     - The execution time was about 4,000 times faster.
#
#
# - We will understand the power of using databases systems in this class.
#     - Specialize "query languages."
#     - Performance optimization for data centric applications.

# %% [markdown]
# ## Country, Region, City Information
#
#
# - I did some exploration. There are several types of location names:
#     - Countries
#     - "States" within countries.
#     - Other "things" in states: cities, specific hot spots (e.g. nursing homes), etc.
#
#
# - How do I know what is what? Well, there are also on-line sources of information on countries, regions, ... ...
#
#
# - There are downloadable sources of information about country, city, state, etc.
#
#
# - I used the data from a [GitHub project.](https://github.com/dr5hn/countries-states-cities-database) I loaded into a [MySQL](https://en.wikipedia.org/wiki/MySQL) database server on my laptop. The data is 3 files:
#     - ```cities```
#     - ```states```
#     - ```countries```
#     - And linked by IDs in the files.

# %% [markdown]
# - What does the location information look like?
#
#
# - One way to represent information about the data (known as [metadata](https://en.wikipedia.org/wiki/Metadata)) is to use an [Entity Relationship Diagram](https://en.wikipedia.org/wiki/Entity%E2%80%93relationship_model).
#
# <hr style="height:2px;">
#
# | <img src = "../../images/country_state_city_schema.png"> |
# | :---: |
# | __An Example ER Diagram__ |
#
# <hr style="height:2px;">
#
#
# - We will learn about ER diagrams and modeling in this course.

# %% [markdown]
# - What are some things that I can do with the data?
#
#
# - What are the cities in Massachusetts?

# %%
# %%sql ma_towns <<
#         select * from
#             (select
#                 countries.name as country_name, countries.iso2 as country_code,
#                 cities.name as city_name,
#                 (select states.name as state_name from states where
#                      states.id=cities.state_id) as state_name
#                 from
#                     countries join cities on countries.id = cities.country_id) as b
#         where state_name='Massachusetts';
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 404 rows affected.
# Returning data to local variable ma_towns

# %%
print("The towns in MA are ... ...")
print(ma_towns)
# Out:
# The towns in MA are ... ...
# +---------------+--------------+---------------------------+---------------+
# |  country_name | country_code |         city_name         |   state_name  |
# +---------------+--------------+---------------------------+---------------+
# | United States |      US      |          Abington         | Massachusetts |
# | United States |      US      |           Acton           | Massachusetts |
# | United States |      US      |          Acushnet         | Massachusetts |
# | United States |      US      |      Acushnet Center      | Massachusetts |
# | United States |      US      |           Adams           | Massachusetts |
# | United States |      US      |           Agawam          | Massachusetts |
# | United States |      US      |          Amesbury         | Massachusetts |
# | United States |      US      |          Amherst          | Massachusetts |
# | United States |      US      |       Amherst Center      | Massachusetts |
# ...

# %% [markdown]
# ## An Example of Data From Several Sources: IHME and Geography
#
# - What are the state names in the United States? I happen to know the country code.

# %%
# %sql select name from states where country_code="US"
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 66 rows affected.
# [('Howland Island',),
#  ('Delaware',),
#  ('Alaska',),
#  ('Maryland',),
#  ('Baker Island',),
#  ('Kingman Reef',),
#  ('New Hampshire',),
#  ('Wake Island',),
#  ('Kansas',),
#  ('Texas',),
#  ('Nebraska',),
#  ('Vermont',),
#  ('Jarvis Island',),
#  ('Hawaii',),
#  ('Guam',),
#  ('United States Virgin Islands',),
#  ('Utah',),
#  ('Oregon',),
#  ('California',),
#  ('New Jersey',),
#  ('North Dakota',),
#  ('Kentucky',),
#  ('Minnesota',),
#  ('Oklahoma',),
#  ('Pennsylvania',),
#  ('New Mexico',),
#  ('American Samoa',),
#  ('Illinois',),
#  ('Michigan',),
#  ('Virginia',),
#  ('Johnston Atoll',),
#  ('West Virginia',),
#  ('Mississippi',),
#  ('Northern Mariana Islands',),
#  ('United States Minor Outlying Islands',),
#  ('Massachusetts',),
#  ('Arizona',),
#  ('Connecticut',),
#  ('Florida',),
#  ('District of Columbia',),
#  ('Midway Atoll',),
#  ('Navassa Island',),
#  ('Indiana',),
#  ('Wisconsin',),
# ...

# %% [markdown]
# - So, let's find the maximum deaths per state in the US.

# %%
# %%sql select location_name, round(max(totdea_mean),0) as total_deaths from ihmefast where
#     location_name in (select name from states where country_code="US")
#     group by location_name order by total_deaths desc
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 54 rows affected.
# [('New York', 35379.0),
#  ('California', 32692.0),
#  ('Texas', 27435.0),
#  ('Florida', 19358.0),
#  ('New Jersey', 18734.0),
#  ('Massachusetts', 12906.0),
#  ('Pennsylvania', 12420.0),
#  ('Georgia', 11288.0),
#  ('Illinois', 9995.0),
#  ('Ohio', 9041.0),
#  ('North Carolina', 8862.0),
#  ('Michigan', 8771.0),
#  ('Arizona', 7946.0),
#  ('Louisiana', 7901.0),
#  ('Alabama', 7334.0),
#  ('Indiana', 6248.0),
#  ('Virginia', 5842.0),
#  ('Colorado', 5795.0),
#  ('Connecticut', 5474.0),
#  ('Missouri', 5436.0),
#  ('Maryland', 5219.0),
#  ('Washington', 5075.0),
#  ('Tennessee', 4985.0),
#  ('South Carolina', 4556.0),
#  ('Wisconsin', 3708.0),
#  ('Mississippi', 3464.0),
#  ('Minnesota', 3191.0),
#  ('Nevada', 3152.0),
#  ('Maine', 3013.0),
#  ('Oregon', 2992.0),
#  ('Oklahoma', 2967.0),
#  ('Kentucky', 2941.0),
#  ('Iowa', 2331.0),
#  ('Puerto Rico', 2259.0),
#  ('Kansas', 2245.0),
#  ('Arkansas', 2234.0),
# ...

# %% [markdown]
# - What did the database engine do to produce the result?
#
# <br><br>
# <hr style="height:1px;">
#
# | <img src = "../../images/sample_query_plan.png" width="900px"> |
# | :---: |
# | __Example Query Plan__ |
#
# <hr style="height:1px;">
# <br><br>
#
#
# - Basically and overly simplistically, the query engine parses and compiles the SQL statement into code to run the query. The process looks is:
#
#
# <br><br>
# <hr style="height:1px;">
#
# | <img src = "../../images/queryprocessing.jpg" width="900px"> |
# | :---: |
# | __An Example ER Diagram__ |
#
# <hr style="height:1px;">

# %% [markdown]
# - You will learn in this course how database engines perform these functions.

# %% [markdown]
# ### Example Summary
#
#
# - You are probably thinking ... "What did he just do? How did he just do it?"
# <br><br>
#
# <hr style="height:2px;">
#
# | <img src = "../../images/wizard.png"> |
# | :---: |
# | __Would You Like to Be a Wizard?__ |
#
# <hr style="height:2px;">
# <br><br>
#
# - You will be a wizard by the end of the semester.
#
#
# - Well, if you take the programming track. If you take the non-programming track, you may still be a muggle. Just kidding.
#
# <br><br>
#
# <hr style="height:2px;">
#
# | <img src = "../../images/muggles.jpg" width="700px;"> |
# | :---: |
# | __Muggles__ |
#
# <hr style="height:2px;">

# %% [markdown]
# # Lecture Slides
#
#
# - Switch to lecture slides.

# %% [markdown]
# # Let's Play with the Database!
#
# ## The Database Schema
#
#
# <hr style="height:2px;">
#
# | <img src = "../../images/book_schema.png" width="900px;"> |
# | :---: |
# | __Sample Database: Database Systems Concepts__ |
#
# <hr style="height:2px;">

# %% [markdown]
# ## Some Queries

# %% [markdown]
# __Who are the students?__

# %%
# Use the course example database. This is similar to changing to a directory that contains files.
# %sql use aaBookDB;
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 0 rows affected.
# []

# %%
# %sql select * from student;
# Out:
#  * mysql+pymysql://root:***@localhost/AAF20W4111
# 13 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')),
#  ('19991', 'Brandt', 'History', Decimal('80')),
#  ('23121', 'Chavez', 'Finance', Decimal('110')),
#  ('44553', 'Peltier', 'Physics', Decimal('56')),
#  ('45678', 'Levy', 'Physics', Decimal('46')),
#  ('54321', 'Williams', 'Comp. Sci.', Decimal('54')),
#  ('55739', 'Sanchez', 'Music', Decimal('38')),
#  ('70557', 'Snow', 'Physics', Decimal('0')),
#  ('76543', 'Brown', 'Comp. Sci.', Decimal('58')),
#  ('76653', 'Aoi', 'Elec. Eng.', Decimal('60')),
#  ('98765', 'Bourikas', 'Elec. Eng.', Decimal('98')),
#  ('98988', 'Tanaka', 'Biology', Decimal('120'))]
